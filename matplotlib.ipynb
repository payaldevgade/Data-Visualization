# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp311-cp311-win_amd64.whl.metadata (80 kB)
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ------------------- ------------------ 41.0/80.3 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 80.3/80.3 kB 496.6 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl.metadata (121 kB)
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      --------- ----------------------------- 30.7/121.0 kB 1.4 MB/s eta 0:00:01
#      --------------------- --------------- 71.7/121.0 kB 787.7 kB/s eta 0:00:01
#      ---------------------------- -------- 92.2/121.0 kB 751.6 kB/s eta 0:00:01
#      --------------------------------- -- 112.6/121.0 kB 656.4 kB/s eta 0:00:01
#      ------------------------------------ 121.0/121.0 kB 545.8 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\users\payal\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\payal\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\payal\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\payal\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp311-cp311-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.3 MB 812.7 kB/s eta 0:00:12
#     --------------------------------------- 0.1/9.3 MB 1.0 MB/s eta 0:00:09
#    - -------------------------------------- 0.2/9.3 MB 1.3 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/9.3 MB 1.6 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/9.3 MB 1.8 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/9.3 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.3 MB 2.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.3 MB 2.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.2/9.3 MB 2.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.5/9.3 MB 2.9 MB/s eta 0:00:03
#    ------- -------------------------------- 1.7/9.3 MB 3.1 MB/s eta 0:00:03
#    -------- ------------------------------- 1.9/9.3 MB 3.3 MB/s eta 0:00:03
#    --------- ------------------------------ 2.2/9.3 MB 3.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.4/9.3 MB 3.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------ --------------------------- 2.8/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------ --------------------------- 3.0/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.2/9.3 MB 3.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.3 MB 3.5 MB/s eta 0:00:02
#    --------------- ------------------------ 3.6/9.3 MB 3.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.8/9.3 MB 3.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.3 MB 3.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.3 MB 3.7 MB/s eta 0:00:02
#    ------------------ --------------------- 4.4/9.3 MB 3.7 MB/s eta 0:00:02
#    ------------------- -------------------- 4.5/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------------- -------------------- 4.5/9.3 MB 3.6 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.3 MB 3.6 MB/s eta 0:00:02
#    -------------------- ------------------- 4.8/9.3 MB 3.5 MB/s eta 0:00:02
#    -------------------- ------------------- 4.8/9.3 MB 3.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.3 MB 3.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.1/9.3 MB 3.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.3/9.3 MB 3.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.4/9.3 MB 3.4 MB/s eta 0:00:02
#    ------------------------ --------------- 5.7/9.3 MB 3.4 MB/s eta 0:00:02
#    ------------------------- -------------- 5.9/9.3 MB 3.5 MB/s eta 0:00:01
#    -------------------------- ------------- 6.2/9.3 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.3/9.3 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.5/9.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.7/9.3 MB 3.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.9/9.3 MB 3.5 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.3 MB 3.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.3 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 7.5/9.3 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 7.7/9.3 MB 3.6 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.0/9.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.3/9.3 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 3.5 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    ------------ --------------------------- 71.7/225.2 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 194.6/225.2 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 225.2/225.2 kB 2.3 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.4 MB 2.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.4 MB 3.0 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.4 MB 3.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.4 MB 3.3 MB/s eta 0:00:01
#    -------------- ------------------------- 0.9/2.4 MB 3.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.1/2.4 MB 3.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.4/2.4 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.4 MB 4.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.4 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 2.0/2.4 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 2.2/2.4 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 4.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 2.0 MB/s eta 0:00:00
# Downloading pillow-12.3.0-cp311-cp311-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#     --------------------------------------- 0.2/7.2 MB 5.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/7.2 MB 4.6 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/7.2 MB 4.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/7.2 MB 4.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.2 MB 4.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/7.2 MB 4.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.2 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.7/7.2 MB 4.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.9/7.2 MB 4.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.9/7.2 MB 4.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.0/7.2 MB 4.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.2 MB 3.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.2 MB 3.6 MB/s eta 0:00:02
#    ------------ --------------------------- 2.2/7.2 MB 3.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.2/7.2 MB 3.2 MB/s eta 0:00:02
#    ------------ --------------------------- 2.3/7.2 MB 3.1 MB/s eta 0:00:02
#    ------------- -------------------------- 2.4/7.2 MB 3.0 MB/s eta 0:00:02
#    ------------- -------------------------- 2.5/7.2 MB 3.0 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.2 MB 2.9 MB/s eta 0:00:02
#    -------------- ------------------------- 2.7/7.2 MB 2.9 MB/s eta 0:00:02
#    --------------- ------------------------ 2.8/7.2 MB 2.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.0/7.2 MB 2.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.2 MB 3.0 MB/s eta 0:00:02
#    ------------------ --------------------- 3.3/7.2 MB 3.0 MB/s eta 0:00:02
#    ------------------- -------------------- 3.6/7.2 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 3.8/7.2 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 4.0/7.2 MB 3.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.3/7.2 MB 3.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.5/7.2 MB 3.3 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.2 MB 3.4 MB/s eta 0:00:01
#    --------------------------- ------------ 4.9/7.2 MB 3.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.1/7.2 MB 3.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.3/7.2 MB 3.4 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 3.5 MB/s eta 0:00:01
#    ------------------------------- -------- 5.6/7.2 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 5.8/7.2 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.0/7.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.2/7.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.5/7.2 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 6.7/7.2 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.0/7.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  7.2/7.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 3.4 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.8 kB ? eta -:--:--
#    ---------------------------------------- 122.8/122.8 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: C:\Users\payal\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Matplotlib Basics

# %%
x = np.linspace(0,5,11)
x

y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
x = np.linspace(0,5,11)
x

y = x ** 3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.title("Hello")
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel("x axis")
# Out:
# Text(0.5, 0, 'x axis')

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
# Subplots in matplotlib

# %%
plt.subplot(2,2,1)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.plot(x,y)

plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.plot(x,y)

plt.subplot(2,2,3)
plt.plot(x,y)

plt.subplot(2,2,4)
plt.plot(x **2,y **2)

# %%
plt.subplot(6,6,1)
# Out:
# <Axes: >

# %%
plt.subplot(6,6,1)
plt.subplot(6,6,2)
plt.subplot(6,6,3)
plt.subplot(6,6,4)
# Out:
# <Axes: >

# %%
# object oriented way

# %%
# Matplotlib allow the aspect ratio, DPI and figure size to be specified when the figure object is created .
# you can use the figsize and DPI keyword arguments 

# figsize is a tuple of the width and height of the figure in inches
#DPI is the dots-per-inch (pixel per inch)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 11)
y = x ** 3

fig = plt.figure(figsize=(20, 8),dpi = 100 )

axis1 = fig.add_axes([0.1, 0.55, 0.8, 0.35])
axis1.plot(x, y)

axis2 = fig.add_axes([0.1, 0.1, 0.8, 0.35])
axis2.plot(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 11)
y = x ** 3

fig = plt.figure(figsize=(20, 8),dpi = 50 )

axis1 = fig.add_axes([0.1, 0.55, 0.8, 0.35])
axis1.plot(x, y)

axis2 = fig.add_axes([0.1, 0.1, 0.8, 0.35])
axis2.plot(x, y)

plt.show()

# %%
fig = plt.figure

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.9])

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axis1.plot(x,y)

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axis1.plot(x,y)

axis2 = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axis1.plot(x,y)

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axis1.plot(x,y)

axis2 = fig.add_axes([0.1, 0.1, 0.6, 0.7])
axis1.plot(x,y)

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 1, 1])
axis1.plot(x,y)

axis2 = fig.add_axes([0.1, 0.1, .3, .3])
axis1.plot(x,y)

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 1, 1])
axis1.plot(x,y)

axis2 = fig.add_axes([0.3, 0.1, .3, .3])
axis1.plot(x,y)

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 1, 1])
axis1.plot(x,y)

axis2 = fig.add_axes([0.3, 0.4, .3, .3])
axis1.plot(x,y)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Types of plot

# %%
# SCATTER
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 9.,  8., 11.,  7.,  7., 15.,  7., 18.,  9.,  9.]),
#  array([  2. , 100.9, 199.8, 298.7, 397.6, 496.5, 595.4, 694.3, 793.2,
#         892.1, 991. ]),
#  <BarContainer object of 10 artists>)

# %%
# HISTOGRAM
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
# BOX-PLOT
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2582a6d4d10>,
#   <matplotlib.lines.Line2D at 0x2582a6d5590>],
#  'caps': [<matplotlib.lines.Line2D at 0x2582a6d5dd0>,
#   <matplotlib.lines.Line2D at 0x2582a6d6590>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2582a6d4650>],
#  'medians': [<matplotlib.lines.Line2D at 0x2582a6d6d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2582a6d7510>],
#  'means': []}

# %%
# saving plots

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %%
# working with image

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('image.jpg')
img
# Out:
# array([[[  5, 128, 231],
#         [  5, 128, 231],
#         [  5, 128, 231],
#         ...,
#         [  4, 127, 230],
#         [  5, 128, 231],
#         [  6, 129, 232]],
#
#        [[  5, 128, 231],
#         [  5, 128, 231],
#         [  5, 128, 231],
#         ...,
#         [  4, 127, 230],
#         [  5, 128, 231],
#         [  6, 129, 232]],
#
#        [[  5, 128, 231],
#         [  5, 128, 231],
#         [  5, 128, 231],
#         ...,
#         [  5, 128, 231],
#         [  6, 129, 232],
#         [  6, 129, 232]],
#
#        ...,
#
#        [[237, 221,  37],
#         [232, 217,  38],
#         [231, 216,  53],
#         ...,
#         [228, 204,  20],
#         [229, 201,  29],
#         [255, 250,  79]],
#
#        [[238, 211,   8],
#         [171, 143,   0],
#         [195, 168,  15],
#         ...,
#         [216, 189,   0],
#         [247, 216,  27],
#         [198, 169,   0]],
#
#        [[180, 149,   0],
#         [210, 177,   0],
#         [199, 164,  18],
#         ...,
#         [255, 233,  25],
#         [237, 205,   6],
#         [243, 211,  15]]], shape=(1024, 1024, 3), dtype=uint8)

# %%
img = mpimg.imread('image.jpg')
plt.imshow(img)

# %%
img = mpimg.imread('image.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1023.5), np.float64(1023.5), np.float64(-0.5))

# %%
# CROP THE IMAGE

# %%
cropped_img = img[50:200, 100:300]  # crop: rows 50-200, cols 100-300
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %%
# Optional Designing

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color = "pink")

# %%
plt.plot(x,y,color = "yellow")

# %%
plt.plot(x,y,color = "purple")

# %%
import matplotlib.pyplot as plt
import numpy as np

xaxis = np.linspace(0, 10, 100)

fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(xaxis, xaxis + 1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis + 2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis + 3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis + 4, color="red", linewidth=2.00)

# Linestyle options: '-', '--', '-.', ':'

ax.plot(xaxis, xaxis + 5, color="green", lw=3, linestyle="-")
ax.plot(xaxis, xaxis + 6, color="green", lw=3, ls="--")
ax.plot(xaxis, xaxis + 7, color="green", lw=3, ls="-.")

# Custom dash
line, = ax.plot(xaxis, xaxis + 8, color="black", lw=1.5)
line.set_dashes([5, 50, 15, 50])

# Marker examples
ax.plot(xaxis, xaxis + 9, color="blue", lw=3, ls="-", marker="+")
ax.plot(xaxis, xaxis + 10, color="blue", lw=3, ls="--", marker="o")
ax.plot(xaxis, xaxis + 11, color="blue", lw=3, ls="-", marker="s")
ax.plot(xaxis, xaxis + 12, color="blue", lw=3, ls="--", marker="1")

ax.plot(xaxis, xaxis + 13, color="purple", lw=1, ls="-",
        marker="o", markersize=3)

ax.plot(xaxis, xaxis + 14, color="purple", lw=1, ls="-",
        marker="o", markersize=4)

ax.plot(xaxis, xaxis + 15, color="purple", lw=1, ls="-",
        marker="o", markersize=8, markerfacecolor="red")

ax.plot(xaxis, xaxis + 16, color="purple", lw=1, ls="-",
        marker="s", markersize=8,
        markerfacecolor="yellow",
        markeredgewidth=3,
        markeredgecolor="green")

plt.show()
